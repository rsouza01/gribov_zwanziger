# %%
 # %%javascript
    MathJax.Hub.Config({
      TeX: { equationNumbers: { autoNumber: "AMS" } }
    });

# %% [markdown]
# ## QCD InfraRed Extension Code

# %% [markdown]
# $\def\sumint{\sum\!\!\!\!\!\!\!\int\,}$
# $\def\Mp{M_{n,{\bf p}}}$
# $\DeclareMathOperator{\Tr}{Tr}$
#
# # Gribov Zwanziger Framework
#
#
# ## QCD InfraRed Extension
#
# Baseado em evidências de estudos da QCD na rede e equações de Dyson-Schwinger, o propagador do quark em $T=0$ pode ser parametrizado por uma função de massa dependente do momento, compatível com a forma funcional:
#
# \begin{equation}
# 	M_{eff}(p)=\frac{\Delta}{p^2 + m^2} + m_0,
#     \label{eq:mass-function}
# \end{equation}
#
# onde $m_0$ é a massa de corrente do quark.
#
#
# De fato, os dados obtidos por simulações de QCD na rede podem ser ajustados pela Eq. \eqref{eq:mass-function}, com os valores  $\Lambda=0.196\,$GeV$^3$, $m^2=0.639\,$GeV$^2$, e $m_0=0.014 \; MeV$ \citep{bib:Dudal_2013vha}. É interessante notar que, com estes parâmetros, o propagador de quark euclideano
#
# \begin{equation}
#  S(p)=\frac{1}{\gamma\cdot p + M_{eff}(p)}
# \end{equation}
#
# exibe violação de reflexão positiva, indicando o confinamento dos quarks, de acordo com \cite{bib:Capri_2014bsa}.
#
# A função de massa (\ref{eq:mass-function}) pode ser obtida através do propagador de quark de mais baixo nível da teoria dada pela soma da lagrangiana da QCD,
#
# \begin{equation}
#  S_{QCD} = \int d^4x\left[\frac14 F_{\mu\nu}^aF_{\mu\nu}^a + \bar\psi_\alpha^i[i(\gamma_\mu)_{\alpha\beta}D_\mu^{ij} - m_0\delta_{\alpha\beta}\delta^{ij}]\psi_\beta^j
#                 + ib^a\partial_\mu A_\mu^a + \bar c^a \partial_\mu D_\mu^{ab}c^b\right],
# \end{equation}
#
# com a ação BRST
#
# \begin{eqnarray}\label{eq:auxiliary-fields}
#     S_{\xi\lambda} &=& s\int d^4x\left[ -\bar\eta^i_\alpha\partial^2\xi_\alpha^i + \bar\xi^i_\alpha\partial^2\eta_\alpha^i + m^2(\bar\eta^i_\alpha\xi_\alpha^i - \bar\xi_\alpha^i\eta_\alpha^i) \right]\nonumber\\
#     &=& \int d^4x\left[-\bar\lambda_\alpha^i\partial^2\xi_\alpha^i - \bar\xi^i_\alpha\partial^2\lambda_\alpha^i - \bar\eta_\alpha^i\partial^2\theta_\alpha^i + \bar\theta_\alpha^i\partial^2\eta_\alpha^i \right]\nonumber\\
#     &+& \int d^4x\left[ m^2\left(\bar\lambda^i_\alpha\xi_\alpha^i + \bar\xi_\alpha^i\lambda_\alpha^i + \bar\eta_\alpha^i\theta_\alpha^i - \bar\theta_\alpha^i\eta_\alpha^i\right)\right]
# \end{eqnarray}
#
# e o termo de acoplamento
#
# \begin{equation}\label{eq:BRST-breaking}
#     S_M = \int d^4x\left[M_1^2(\bar\xi^i_\alpha\psi_\alpha^i + \bar\psi_\alpha^i\xi_\alpha^i) - M_2(\bar\lambda_\alpha^i\psi_\alpha^i + \bar\psi_\alpha^i\lambda^i_\alpha)\right]
# \end{equation}
#
#
# entre o campo de quarks $\psi$ e o os campos auxiliares $\xi$ e $\lambda$.
#
# A ação resultante
#
# \begin{equation}\label{eq:model}
#  S = S_{QCD} + S_{\xi\lambda} + S_M
# \end{equation}
#
# é renormalizável \citep{bib:baulieu_2009}, sendo equivalente à QCD no limite das altas energias, porém alterando o limite infra-vermelho da teoria (em relação ao panorama perturbativo). Os campos auxiliares do setor de quarks em \eqref{eq:model} podem ser integrados, provendo uma teoria efetiva de quarks onde a ação não local pode ser expressada, em uma aproximação quadrática, como
#
#
# \begin{equation}\label{eq:non-local-action}
#  S_{nl}=\int d^4x\,\bar\psi_\alpha^i\left[i(\gamma_\mu)_{\alpha\beta}\delta^{ij}\partial_\mu -
#            \delta^{ij}\delta_{\alpha\beta}\left(\frac{2M_1^2M_2}{-\partial^2+m^2} + m_0 \right)\right]\psi^j_\beta.
# \end{equation}
#
#
# Nota-se que neste modelo a função de massa do quark (Eq.\ref{eq:mass-function}) pode ser derivada diretamente da ação efetiva (Eq.\ref{eq:non-local-action}), com $\Lambda\equiv 2M_1M_2$.)
#
#
# ## A função de Partição
#
# Em baixas ordens, a teoria definida pela Eq.\eqref{eq:model} possui uma ação quadrática. Logo, sua função de grande partição pode ser calculada de maneira exata através de técnicas de teoria de campos à temperatura finita.
#
# Para introduzir temperatura no modelo, faz-se a compactificação de uma direção euclidiana (a 4-direção por convenção), enquanto que a introdução do potencial químico não é trivial.
#
# Partindo da ação local  dada pelq Eq.\eqref{eq:model}, calcula-se a Hamiltoniana ${\cal H}$. Identificando o número de quarks com a carga associada à simetria global de transformação $U(1)$
#
# \begin{equation}
#  \psi(x)\;\;\longrightarrow\;\;e^{-i\alpha}\psi(x),
# \end{equation}
#
# usa-se o teorema de Noether para calcular a densidade de corrente correspondente $j^\mu$, fazendo que ${\cal N}=\int d^3x j^0$ seja o operador de número de quarks.
#
# A função de grande partição resultante
#
# \begin{equation}
#  Z(T,\mu) = Tr\exp\left[-\frac{{\cal H}-\mu {\cal N}}{T}\right],
# \end{equation}
#
# pode ser convertida em uma integral funcional e calculada diretamente \citet{bib:Guimaraes_2015vra}.
# É possível dividir o resultado em duas partes: Um termo sendo $\mu-$independente e o outro $(T,\mu)-$dependente,
#
#
# \begin{eqnarray}\label{eq:logZ_T0_and_mu}
#  \frac{\log Z(T,\mu)}{2\beta VN_cN_f} &=& \sumint\log\left\{\beta^2\left[{\bf p}^2 + \Mp^2(0) +\omega_n^2\right]\right\} + \sumint\log\left\{\frac{{\bf p}^2 + \Mp^2(\mu) - (i\omega_n+\mu)^2}{{\bf p}^2 + \Mp^2(0) +\omega_n^2}\right\}\\
#                             &\equiv&  \frac{\log Z(T,0)}{2\beta VN_cN_f} +  \frac{\log Z^{(\mu)}(T,\mu)}{2\beta VN_cN_f},
# \end{eqnarray}
#
# onde a notação soma-integral foi utilizada,
#
# \begin{equation}
#  \sumint (\cdots) \equiv T \sum_{n=-\infty}^\infty\int\frac{d^3p}{(2\pi)^3}(\cdots).
# \end{equation}
#
# O termo associado à $\mu=0$ pode ser dividido em uma soma de quatro termos, dois dos quais correspondem à pressões positivas com massas conjugadas complexas, um à uma partícula com massa real e outro com contribuição negativa à pressão. Cada um destes termos podem ser calculados diretamente como a pressão de um gás livre. Subtraindo a contribuição da energia do vácuo, chega-se em
#
#
# \begin{equation}\label{eq:log-Z_zero_mu-final}
#  \log Z(T,0) = \log Z_0 + 4N_cN_f V\int\frac{d^3p}{(2\pi)^3}
#       \log\left[\frac{\left(1+e^{-\beta\varphi_1}\right)\left(1+e^{-\beta\varphi_2}\right)\left(1+e^{-\beta\varphi_3}\right)}{\left(1+e^{-\beta\varphi_0}\right)^2}\right],
# \end{equation}
#
# para a contribuição de $\mu=0$, onde
#
# \begin{equation}
#  \log Z_0 = 2N_cN_f \beta V\int\frac{d^3p}{(2\pi)^3}\left(\varphi_1+\varphi_2+\varphi_3-2\varphi_0\right)
# \end{equation}
#
# é a contribuição do vácuo. As grandezas $\varphi_i$ ($i=0,1,2,3$) são funções do momento interno $p^2$ \citep{bib:Guimaraes_2015vra}.
#
# O termo dependente de $\mu$ é dado por
#
# \begin{equation}\label{eq:logZ_finite-mu}
#  \log Z^{(\mu)}(T,\mu) = 2\beta VN_cN_f\sumint\log\left\{\frac{{\bf p}^2 + M_{n,{\bf p}}^2(\mu) - (i\omega_n+\mu)^2}{{\bf p}^2 + M_{n,{\bf p}}^2(0) +\omega_n^2}\right\}.
# \end{equation}
#
# Uma expressão fechada para Eq.\eqref{eq:logZ_finite-mu} pode ser encontrada para o limite de $T=0$. Utilizando o teorema de Cauchy, pode-se escrever
#
# \begin{eqnarray}\label{eq:logZ_finite-mu_zeroT}
#   \log Z(0,\mu) &=& \log Z^{(\mu)}(0,\mu) = 2\beta VN_cN_f\int\frac{d^3p}{(2\pi)^3}\int_{-\infty}^{\infty}\frac{d\theta}{2\pi}f(i\theta+\mu)\\
#                 &=& 2\beta VN_cN_f\int\frac{d^3p}{(2\pi)^3}\int_{0}^{\infty}\frac{d\theta}{2\pi}\left[f(i\theta+\mu)+f(-i\theta+\mu)\right],
# \end{eqnarray}
#
# onde
#
# \begin{equation}
#  f(\xi) := \log\left\{\frac{\Omega_{{\bf p}}^2(\xi^2) - \xi^2}{\Omega_{{\bf p}}^2[(\xi-\mu)^2] - (\xi-\mu)^2}\right\}
# \end{equation}
#
# e
#
# \begin{equation}\label{eq:nonlocal_dispersion_relation}
# \Omega_{{\bf p}}^2(\zeta):={\bf p}^2 + \left[\frac{M_3}{-\zeta+{\bf p}^2 + m^2} + m_0 \right]^2.
# \end{equation}
#
# A expressão acima permite calcular a função de partição (Equação \eqref{eq:logZ_T0_and_mu}) de maneira exata para que seja possível obter as quantidades termodinâmicas associadas.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))   
# %matplotlib inline

import math
import cmath
import numpy as np
import scipy.integrate as integ
import matplotlib.pyplot as plt
import matplotlib as mpl

#region Auxiliary definitions

def _infunc(x,func,gfun,hfun,more_args):
    a = gfun(x)
    b = hfun(x)
    myargs = (x,) + more_args
    return integ.quad(func,a,b,args=myargs)[0]

def custom_dblquad(func, a, b, gfun, hfun, args=(), epsabs=1.49e-8, epsrel=1.49e-8, maxp1=50, limit=50):
    return integ.quad(_infunc, a, b, (func, gfun, hfun, args), epsabs=epsabs, epsrel=epsrel, maxp1=maxp1, limit=limit)

#endregion

#region GZ functions

Nc = 3
Nf = 2

M3 = 0.196
m2 = 0.639
MPrime = 0.014


def Omega2(zeta, p, mp):
    return p**2. + (M3/(-zeta + p**2. + m2) + mp)**2.

def integrandTheta(theta, p, mu, mp):
    
    return 1./(2.*math.pi)**3.*(4.*math.pi)* p**2.* \
        (2.*Nc*Nf*(1./2./math.pi)*(2.)* \
             math.log(
                 abs(
                     (Omega2((1j*theta + mu)**2., p, mp) - (1j*theta + mu)**2.)/
                     (Omega2(-theta**2., p,  mp) + theta**2.)
                 )
             )
        )


def pressureZeroT(mu, mp):
    def lim_inf_theta(p):
        return 0.

    def lim_sup_theta(p):
        return np.inf

    pressure_zero_t, err_dblquad = integ.dblquad(integrandTheta, 0, mu, lim_inf_theta, lim_sup_theta, args=(mu, mp))
    # pressure_zero_t, err_dblquad = custom_dblquad(integrandTheta, 0., mu, lim_inf_theta, lim_sup_theta, args=(mu, mp), maxp1=500, limit=500)
    return pressure_zero_t
    
    

#endregion

#region Main program

# Cálculo da pressão desde mu=0.01GeV até mu=1.5GeV    
mu_range = np.linspace(0.01, 1.51, 100)

pressure_zero_T_list = []    
pressure_norm_zero_T_list = []    

#print (Nf*Nc/12./math.pi**2.) #GeV^4

#print (Nf*Nc/12./math.pi**2.) 

for mu in mu_range:
    pressure = pressureZeroT(mu, MPrime) #GeV^4
    pressureNormalized = pressureZeroT(mu, MPrime)/(Nf*Nc*mu**4./12./math.pi**2.) #GeV^4
    
    # 1=197 1e-3 GeV * fm
    # GeV = 1/(197e3 fm = 1/(1.97e5 fm)

    #pressure = pressure * (1.97e5)**-3
    #pressureNormalized = pressureNormalized * (1.97e5)**-3.

    pressure_zero_T_list.append(pressure)
    pressure_norm_zero_T_list.append(pressureNormalized) #GeV^4
    
    

#print pressure_zero_T_list

mpl.rcParams['figure.figsize'] = (17,17)

plt.figure()

plt.subplot(211)             # the first subplot in the first figure
plt.title('QCD IRE EoS')

plt.xlabel('Chemical Potential [GeV]')
plt.ylabel('Pressure [GeV^4]')

plt.grid()
plt.plot(mu_range, pressure_zero_T_list)

# the second subplot in the first figure
plt.subplot(212)
plt.title('QCD IRE EoS - normalized')

plt.xlabel('Chemical Potential [GeV]')
#plt.ylabel('Pressure [GeV^4]')

plt.grid()
plt.plot(mu_range, pressure_norm_zero_T_list)

plt.show()

#endregion
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Equação de Estado

# %%
import scipy.interpolate as si


#print('{0}, {1}'.format(mu_range, pressure_zero_T_list))


f_pressure_zero_T_list = si.interp1d(mu_range, pressure_zero_T_list, kind='cubic')

mpl.rcParams['figure.figsize'] = (17,17)
plt.figure()

plt.subplot(211)             # the first subplot in the first figure
plt.title('QCD IRE EoS - interpolated')

plt.xlabel('Chemical Potential [GeV]')
plt.ylabel('Pressure [GeV^4]')

plt.grid()
plt.plot(mu_range, f_pressure_zero_T_list(mu_range))


plt.show()

# %% [markdown]
# ## Densidade Bariônica
#
# Usando a função interpolada \textit{f_pressure_zero_T_list}
# \begin{equation}
#  n_B = \frac{\partial P}{\partial \mu}
# \end{equation}

# %%
mu_range, f_pressure_zero_T_list


x = mu_range
y = f_pressure_zero_T_list(x)

dy = np.zeros(y.shape,np.float)
dy[0:-1] = np.diff(y)/np.diff(x)
dy[-1] = (y[-1] - y[-2])/(x[-1] - x[-2])

mpl.rcParams['figure.figsize'] = (17,17)
plt.figure()

plt.subplot(211)             # the first subplot in the first figure
plt.title('QCD IRE EoS - Number Density')

plt.xlabel('Chemical Potential [GeV]')
plt.ylabel('Number Density [fm^(-3)]')

plt.grid()
plt.plot(mu_range, dy)


plt.show()
